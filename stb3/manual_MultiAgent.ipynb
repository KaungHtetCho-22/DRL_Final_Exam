# %%
import numpy as np
import cv2 as cv
import os
import time
import heapq
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from env_eval_multiAgents import MobileRobot
from utils import plot_learning_curve, plot_testing_curve

device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')
torch.cuda.empty_cache()


###################################################################
#                      MANUAL CONTROL                             #
###################################################################
env = MobileRobot(2)
env.reset_pathPlanning1()
env.render_pathPlanning1()
key = cv.waitKey(0)
done = [False, False]
complete = [False, False]
action = [0,0]
while True:
    if key == ord('7'):
        action[0] = 0
        action[1] = 0
    elif key == ord('8'):
        action[0] = 1
        action[1] = 1
    elif key == ord('9'):
        action[0] = 2
        action[1] = 2
    elif key == ord('4'):
        action[0] = 3
        action[1] = 3
    elif key == ord('6'):
        action[0] = 4
        action[1] = 4
    elif key == ord('1'):
        action[0] = 56
        action[1] = 5
    elif key == ord('2'):
        action[0] = 6
        action[1] = 6
    elif key == ord('3'):
        action[0] = 7
        action[1] = 7     
    elif key == ord('q'):
        break
         
    state, reward, done, info = env.step_pathPlanning1(action)     

    if (done[0]):
        complete[0] = True
    if (done[1]):
        complete[1] = True
    print('reward', reward)
    print('done', done, 'info', info)
    print(complete)
    if key == ord('q'):
        break
    if  (complete[0] and complete[1]) :
        complete[0] = False
        complete[1] = False
        env.reset_pathPlanning1()
    env.render_pathPlanning1()
    key = cv.waitKey(0)
# Out:
# reward [-0.605039675470999, -2.351955814074546]
# done [False, False] info ['', '']
# [False, False]
# reward [-0.7837754170016826, -2.464089183493985]
# done [False, False] info ['', '']
# [False, False]
# reward [-1.0095430074371647, -2.544677828751154]
# done [False, False] info ['', '']
# [False, False]
# reward [-1.2741788233105924, -2.6031905517271268]
# done [False, False] info ['', '']
# [False, False]
# reward [-1.554248301435598, -2.646367194255558]
# done [False, False] info ['', '']
# [False, False]
# reward [0.0, -2.1305641169140044]
# done [False, False] info ['', '']
# [False, False]
# reward [-0.19202168650487028, -0.8243145604545976]
# done [False, False] info ['', '']
# [False, False]
# reward [-0.25373001205953205, -0.893533223887248]
# done [False, False] info ['', '']
# [False, False]
# reward [-0.3431457505076194, -0.964331152381801]
# done [False, False] info ['', '']
# [False, False]
# reward [-1.6568542494923806, -1.035668847618199]
# done [False, False] info ['', '']
# [False, False]
# reward [-1.746269987940468, -1.106466776112752]
# done [False, False] info ['', '']
# [False, False]
# reward [-1.8079783134951297, -1.1756854395454024]
# done [False, False] info ['', '']
# [False, False]
# reward [-1.8511551973705709, -1.2423987152846827]
# done [False, False] info ['', '']
# [False, False]
# reward [-1.88201416170061, -1.30584896875747]
# done [False, False] info ['', '']
# [False, False]
# reward [-1.9045858917969447, -1.3654774644093113]
# done [False, False] info ['', '']
# [False, False]
# reward [-1.9214718124729036, -1.4209296307707113]
# done [False, False] info ['', '']
# [False, False]
# reward [-1.9343702964506182, -1.4720396540985696]
# done [False, False] info ['', '']
# [False, False]
# reward [-1.9444107299538924, -1.5188014804961405]
# done [False, False] info ['', '']
# [False, False]
# reward [-1.9523598680619259, -1.5613335569920146]
# done [False, False] info ['', '']
# [False, False]
# reward [-1.9587492698255922, -1.599843280679604]
# done [False, False] info ['', '']
# [False, False]
# reward [-1.9639549176989881, -1.6345950998209169]
# done [False, False] info ['', '']
# [False, False]
# reward [-1.9682478062106181, -1.665884259957025]
# done [False, False] info ['', '']
# [False, False]
# reward [-1.9718266941023366, -1.6940166986805316]
# done [False, False] info ['', '']
# [False, False]
# reward [-0.028173305897663425, -0.3059833013194684]
# done [False, False] info ['', '']
# [False, False]
# reward [-0.03175219378938188, -0.33411574004297506]
# done [False, False] info ['', '']
# [False, False]
# reward [-0.03604508230101189, -0.3654049001790831]
# done [False, False] info ['', '']
# [False, False]
# reward [-0.041250730174407835, -0.4001567193203961]
# done [False, False] info ['', '']
# [False, False]
# reward [-0.04764013193807415, -0.4386664430079854]
# done [False, False] info ['', '']
# [False, False]
# reward [-0.055589270046107586, -0.4811985195038595]
# done [False, False] info ['', '']
# [False, False]
# reward [-0.0656297035493818, -0.5279603459014304]
# done [False, False] info ['', '']
# [False, False]
# reward [-0.6699768946415432, -1.9004695147483197]
# done [False, False] info ['', '']
# [False, False]
# reward [-0.8227648552586484, -0.09281441685406411]
# done [False, False] info ['', '']
# [False, False]
# reward [-0.6379751787090342, -1.923948209675693]
# done [False, False] info ['', '']
# [False, False]
# reward [-0.732711476787749, -1.9325130692315504]
# done [False, False] info ['', '']
# [False, False]
# reward [-1.267288523212251, -0.06748693076844958]
# done [False, False] info ['', '']
# [False, False]
# reward [-1.3620248212909658, -0.07605179032430698]
# done [False, False] info ['', '']
# [False, False]
# reward [-1.4467723391908969, -0.08627485154853609]
# done [False, False] info ['', '']
# [False, False]
# reward [-1.521023685404968, -0.09858680172238543]
# done [False, False] info ['', '']
# [False, False]
# reward [-1.5851004245994105, -0.11355622114292885]
# done [False, False] info ['', '']
# [False, False]
# reward [-1.8048013647423229, -1.5084407242636306]
# done [False, False] info ['', '']
# [False, False]
# reward [-1.8318491946715962, -1.5630656983301456]
# done [False, False] info ['', '']
# [False, False]
# reward [-1.8540391790445057, -1.6111998948164512]
# done [False, False] info ['', '']
# [False, False]
# reward [-1.5297611124061525, -0.2409536435218147]
# done [False, False] info ['', '']
# [False, False]
# reward [-1.5777948981440435, -0.27429801428414535]
# done [False, False] info ['', '']
# [False, False]
# reward [-1.620499351813308, -0.3136725174344406]
# done [False, False] info ['', '']
# [False, False]
# reward [-1.6583212442863982, -0.3601596721990834]
# done [False, False] info ['', '']
# [False, False]
# reward [-1.691742152377433, -0.4148995754005895]
# done [False, False] info ['', '']
# [False, False]
# reward [-1.4730371798223587, -0.0315408680377296]
# done [False, False] info ['', '']
# [False, False]
# reward [-0.3718331009303242, -0.16834413498602352]
# done [False, False] info ['', '']
# [False, False]
# reward [-1.2918146916160744, -2.8118882953304682]
# done [False, False] info ['', '']
# [False, False]
# reward [-1.4142135623730951, -2.815967813364474]
# done [False, False] info ['', '']
# [False, False]
# reward [-0.27752859000433894, -0.2283915617432708]
# done [False, False] info ['', '']
# [False, False]
# reward [-0.309719561214461, -0.2693491238770154]
# done [False, False] info ['', '']
# [False, False]
# reward [-0.3466016562333891, -0.3200495206812217]
# done [False, False] info ['', '']
# [False, False]
# reward [-0.3888001051835488, -0.3827808097497396]
# done [False, False] info ['', '']
# [False, False]
# reward [-0.43693430166985436, -0.45993248125592245]
# done [False, False] info ['', '']
# [False, False]
# reward [-0.49155927573636937, -0.5535153575653595]
# done [False, False] info ['', '']
# [False, False]
# reward [-0.5530818874529047, -0.6643367834166094]
# done [False, False] info ['', '']
# [False, False]
# reward [-0.6216539371250533, -0.7909579225849575]
# done [False, False] info ['', '']
# [False, False]
# reward [-0.6970543402717535, -0.9289321881345245]
# done [False, False] info ['', '']
# [False, False]
# reward [-1.3029456597282465, -1.0710678118654755]
# done [False, False] info ['', '']
# [False, False]
# reward [-1.3783460628749467, -1.2090420774150425]
# done [False, False] info ['', '']
# [False, False]
# reward [-0.6216539371250533, -0.7909579225849575]
# done [False, False] info ['', '']
# [False, False]
# reward [-0.6970543402717535, -0.9289321881345245]
# done [False, False] info ['', '']
# [False, False]
# reward [-0.7785856365075698, -1.0710678118654755]
# done [False, False] info ['', '']
# [False, False]
# reward [-1.2214143634924302, -0.9289321881345245]
# done [False, False] info ['', '']
# [False, False]
# reward [-1.9675626258616017, 0.0]
# done [False, False] info ['', '']
# [False, False]
# reward [-1.9723471872733533, 0.0]
# done [False, False] info ['', '']
# [False, False]
# reward [-1.9761569991500192, 0.0]
# done [False, False] info ['', '']
# [False, False]
# reward [-1.9792374775020019, 0.0]
# done [False, False] info ['', '']
# [False, False]
# reward [-3, 0.0]
# done [False, False] info ['hit obstacle', '']
# [False, False]
# reward [-3, 0.0]
# done [False, False] info ['hit obstacle', '']
# [False, False]
# reward [-3, 0]
# done [False, True] info ['hit obstacle', 'reach goal']
# [False, True]
# reward [-3, -2.0]
# done [False, False] info ['hit obstacle', '']
# [False, True]
# reward [-3, -2.0]
# done [False, False] info ['hit obstacle', '']
# [False, True]
# reward [-3, -2.0]
# done [False, False] info ['hit obstacle', '']
# [False, True]
# reward [-3, -2.0]
# done [False, False] info ['hit obstacle', '']
# [False, True]
# reward [-3, -2.0]
# done [False, False] info ['hit obstacle', '']
# [False, True]

# %% [markdown]
# ###
